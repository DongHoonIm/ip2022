# %%
if x == 3 :
  print "X equals 3."

elif x == 2:
  print "X equals 2."

else :
  print "X equals somting else"
print "This is out side the 'if"
# Out:
#   File "<ipython-input-3-1e244f70ba88>", line 2
#     print "X equals 3."
#                       ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("X equals 3.")?

# %%
x = 3

# %%
while x < 5:
  print ((x), "still in the loop")
  x = x + 1
# Out:
# 3 still in the loop
# 4 still in the loop

# %%
x = 6

# %%
while x < 5 :
  print(x, "still in the loop")
